# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the dataset

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Data Quality Check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
plt.subplots(figsize=(30,15))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# **As the ID column is not neccessary for prediction and any other data processing so lets drop it and save it in another variable**

# %%
df_ID = df['Id']

# %%
df_all = df.drop('Id', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
df.shape
# Out:
# (1460, 80)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %% [markdown]
# **Checikg for null values in df**

# %%
sum_of_nullValues = df.isnull().sum()
sum_of_nullValues
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %% [markdown]
# **Creating a list of null values**

# %%
sum_of_nullValues.drop(sum_of_nullValues[sum_of_nullValues == 0].index)
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# # Filling missing values

# %%
numericValues = df._get_numeric_data()
numericValues[:5]
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0          2003       196.0         706           0  ...           0
# 1          1976         0.0         978           0  ...         298
# 2          2002       162.0         486           0  ...           0
# 3          1970         0.0         216           0  ...           0
# 4          2000       350.0         655           0  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %% [markdown]
# **Filling with median**

# %%
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(
lambda v: v.fillna(v.median())
)

# %% [markdown]
# **Filling with mode**

# %%
df['Electrical'].mode()[0]
# Out:
# 'SBrkr'

# %%
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

# %% [markdown]
# **Filling with 0**

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

# %% [markdown]
# **Filling with None**

# %%
df['Alley'] = df['Alley'].fillna('None')
df['MasVnrType'] = df['MasVnrType'].fillna('None')
df['FireplaceQu'] = df['FireplaceQu'].fillna('None')
df['PoolQC'] = df['PoolQC'].fillna('None')
df['Fence'] = df['Fence'].fillna('None')
df['MiscFeature'] = df['MiscFeature'].fillna('None')

# %%
for c in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df[c] = df[c].fillna('None')

# %%
for co in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    df[co] = df[co].fillna('None')

# %% [markdown]
# **Again checking for null if there's any**

# %%
null_val = df.isnull().sum()
null_val
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 80, dtype: int64

# %%
for n in null_val:
    if n !=0:
        print(n)

# %% [markdown]
# Printing null values if there's still any null values left.<br>
# As the code not giving any output it simply means there are no null values left.

# %% [markdown]
# **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbe = LabelEncoder()

# %%
col = ('MSZoning','BldgType','HouseStyle', 'RoofStyle','RoofMatl', 
       'Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual',
       'BsmtCond','BsmtFinType1',
       'Heating','HeatingQC',
       'KitchenQual','FireplaceQu','GarageType','GarageFinish',
       'GarageQual','GarageCond','PavedDrive',
       'PoolQC','Fence','SaleType','SaleCondition')

# %%
for c in col:
    lbe.fit(list(df[c].values))
    df[c] = lbe.transform(list(df[c].values))

# %% [markdown]
# **Changing some numerical column's values to categorical values**

# %%
df['MSSubClass'] = df['MSSubClass'].apply(str)
df['OverallCond'] = df['OverallCond'].apply(str)
df['MoSold'] = df['MoSold'].apply(str)
df['YrSold'] = df['YrSold'].apply(str)

# %%
x = df[['MSSubClass','MSZoning','LotArea','BldgType','HouseStyle','OverallQual','OverallCond','YearBuilt','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MasVnrArea','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtFinType1','BsmtFinSF1','Heating','HeatingQC','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr','KitchenQual','TotRmsAbvGrd','Fireplaces','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageArea','GarageQual','GarageCond','PavedDrive','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','PoolQC','Fence','YrSold','SaleType','SaleCondition']]

y = df[['SalePrice']]

# %% [markdown]
# # Enter some important details of the house :

# %% [markdown]
# **House Style:**
# **0.** One story<br>
# **1.** 1.5Fin One and one-half story: 2nd level finished<br>
# **2.** 1.5Unf One and one-half story: 2nd level unfinished<br>
# **3.** 2Story Two story<br>
# **4.** 2.5Fin Two and one-half story: 2nd level finished<br>
# **5.** 2.5Unf Two and one-half story: 2nd level unfinished<br>
# **6.** SFoyer Split Foyer<br>
# **7.** SLvl Split Level<br>
# <br><br>
#
# **Overall Quality:**<br>
# **1.** Very Poor<br>
# **2.** Poor<br>
# **3.** Fair<br>
# **4.** Below Average<br>
# **5.** Average<br>
# **6.** Above Average<br>
# **7.** Good<br>
# **8.** Very Good<br>
# **9.** Excellent<br>
# **10.** Very Excellent<br>
# <br><br>
#
# **Overall Condition:**<br>
# **1.** Very Poor<br>
# **2.** Poor<br>
# **3.** Fair<br>
# **4.** Below Average<br>
# **5.** Average<br>
# **6.** Above Average<br>
# **7.** Good<br>
# **8.** Very Good<br>
# **9.** Excellent<br>
# **10.** Very Excellent<br>
# <br><br>
#
# **Sale Condition:**<br>
# **0.** Normal - Normal Sale<br>
# **1.** Abnorml - Abnormal Sale - trade, foreclosure, short sale<br>
# **2.** AdjLand - Adjoining Land Purchase<br>
# **3.** Alloca - Allocation - two linked properties with separate deeds, typically condo with a garage unit <br>
# **4.** Family Sale between family members<br>
# **5.** Partial Home was not completed when last assessed (associated with New Homes)<br>

# %%
HouseStyle = input('Enter the house style (in range 0 - 7):  ')
OverallQual = input('Enter the overall quality of the house (in range 1 - 10):  ')
OverallCond = input('Enter the overall condition of the house (in range 1 - 10):  ')
YearBuilt = input('Enter the year in which the house was built: (in range 1872 - 2010):  ')
IstFlrSF = input("Enter the 1st floor's square feet: (in range 334 - 4692):  ")
IIndFlrSF = input("Enter the 2nd floor's square feet: (in range 0 - 2065):  ")
TotalRmsAbvGrd = input('Enter the Total Rooms above ground: (in range 2 - 14):  ')
SaleCondition = input('Enter the sale condition of the house (in range 0 - 5):  ')
# Out:
# Enter the house style (in range 0 - 7):  5
# Enter the overall quality of the house (in range 1 - 10):  9
# Enter the overall condition of the house (in range 1 - 10):  9
# Enter the year in which the house was built: (in range 1872 - 2010):  1956
# Enter the 1st floor's square feet: (in range 334 - 4692):  4500
# Enter the 2nd floor's square feet: (in range 0 - 2065):  2500
# Enter the Total Rooms above ground: (in range 2 - 14):  12
# Enter the sale condition of the house (in range 0 - 5):  3

# %%
HouseStyle = int(HouseStyle)
OverallQual = int(OverallQual)
OverallCond = int(OverallCond)
YearBuilt = int(YearBuilt)
IstFlrSF = int(IstFlrSF)
IIndFlrSF = int(IIndFlrSF)
TotalRmsAbvGrd = int(TotalRmsAbvGrd)
SaleCondition = int(SaleCondition)

# %% [markdown]
# # Splitting the datasets for train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1095, 55), (365, 55), (1095, 1), (365, 1))

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linReg = LinearRegression()

# %%
linReg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
linReg.score(x_test, y_test)
# Out:
# 0.6087430325889387

# %%
linRegOp = linReg.predict(x_test)

# %%
predPrice1 = linReg.predict([[56.89,3,10516.83,0,HouseStyle,OverallQual,OverallCond,YearBuilt,1,1,
                              12,13,2,103.685,3,4,2,4,4,6,443.639,1,0,IstFlrSF,
                              IIndFlrSF,5.84,1515.464,0,0,2,0,3,1,3,TotalRmsAbvGrd,
                              1,3,1,1978,3,472.98,5,5,2,94.244,46.66,21.954,3.409,15.06,
                              2.75,3,4,2007,8,SaleCondition]])

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(x_train, y_train)
# Out:
# <ipython-input-45-da087e9fd0ca>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfr.fit(x_train, y_train)
# RandomForestRegressor()

# %%
rfr.score(x_test, y_test)
# Out:
# 0.842338977661331

# %%
rfrOp = rfr.predict(x_test)

# %%
predPrice2 = rfr.predict([[56.89,3,10516.83,0,HouseStyle,OverallQual,OverallCond,YearBuilt,1,1,
                              12,13,2,103.685,3,4,2,4,4,6,443.639,1,0,IstFlrSF,
                              IIndFlrSF,5.84,1515.464,0,0,2,0,3,1,3,TotalRmsAbvGrd,
                              1,3,1,1978,3,472.98,5,5,2,94.244,46.66,21.954,3.409,15.06,
                              2.75,3,4,2007,8,SaleCondition]])

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
decTreeReg = DecisionTreeRegressor()

# %%
decTreeReg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
decTreeReg.score(x_test, y_test)
# Out:
# 0.7876865432621901

# %%
DecTreeRegOp = decTreeReg.predict(x_test)

# %%
predPrice3 = decTreeReg.predict([[56.89,3,10516.83,0,HouseStyle,OverallQual,OverallCond,YearBuilt,1,1,
                              12,13,2,103.685,3,4,2,4,4,6,443.639,1,0,IstFlrSF,
                              IIndFlrSF,5.84,1515.464,0,0,2,0,3,1,3,TotalRmsAbvGrd,
                              1,3,1,1978,3,472.98,5,5,2,94.244,46.66,21.954,3.409,15.06,
                              2.75,3,4,2007,8,SaleCondition]])

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
rdg = Ridge(alpha = 1.0)

# %%
rdg.fit(x_train, y_train)
# Out:
# Ridge()

# %%
rdg.score(x_test, y_test)
# Out:
# 0.6225353215409455

# %%
predPrice4 = rdg.predict([[56.89,3,10516.83,0,HouseStyle,OverallQual,OverallCond,YearBuilt,1,1,
                              12,13,2,103.685,3,4,2,4,4,6,443.639,1,0,IstFlrSF,
                              IIndFlrSF,5.84,1515.464,0,0,2,0,3,1,3,TotalRmsAbvGrd,
                              1,3,1,1978,3,472.98,5,5,2,94.244,46.66,21.954,3.409,15.06,
                              2.75,3,4,2007,8,SaleCondition]])

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lso = Lasso()

# %%
lso.fit(x_train, y_train)
# Out:
# Lasso()

# %%
lso.score(x_test, y_test)
# Out:
# 0.608932378428686

# %%
predPrice5 = lso.predict([[56.89,3,10516.83,0,HouseStyle,OverallQual,OverallCond,YearBuilt,1,1,
                              12,13,2,103.685,3,4,2,4,4,6,443.639,1,0,IstFlrSF,
                              IIndFlrSF,5.84,1515.464,0,0,2,0,3,1,3,TotalRmsAbvGrd,
                              1,3,1,1978,3,472.98,5,5,2,94.244,46.66,21.954,3.409,15.06,
                              2.75,3,4,2007,8,SaleCondition]])

# %%
predPrice1, predPrice2, predPrice3, predPrice4, predPrice5
# Out:
# (array([[359683.25859343]]),
#  array([477142.9]),
#  array([625000.]),
#  array([[361380.43592863]]),
#  array([495378.61562657]))

# %%
avg_saleprice = df['SalePrice'].mean()

# %%
buy = 0
dont_buy = 0

predPrices = [predPrice1, predPrice2, predPrice3, predPrice4, predPrice5]
for p in predPrices:
    if p < avg_saleprice:
        buy = buy + 1
    else:
        dont_buy = dont_buy + 1

if buy < dont_buy:
    print('You should not invest in this property.')
else:
    print('You can invest in this property')
# Out:
# You should not invest in this property.
